# %%
from glob import glob
from tqdm import tqdm
import subprocess
import pandas as pd
import natsort as ns
import numpy as np
import os
import re

# %%
#Define my directories and location of files
WRK = '/workdir/users/pd378/oilPCR/bulk_process_all_OIL_for_paper/'

F_LIST = WRK+'file_lists/filelist.txt' #a list of the files used for iterating and namings6

#This table connects the second round of uniq reads witht he first round sample specific uniqs
UNIQ_TAB=WRK+"s6_cluster_otu/filtered_uniqs/combined_uniq_tab.txt"
#the parsed tabels generated from the usearch otu clustering 
P_TABLE=WRK+'s6_cluster_otu/filtered_uniqs/uniq_parsed_otu_tab.txt'
#The table of taxonomy generated from using mother to assign taxonomy
TAX_TAB=WRK+'s6_cluster_otu/filtered_uniqs/uniq_clustered_otus.V4_oil.wang.taxonomy' 
#the blast table generated from blasting the targets
BLAST_TABS=WRK+'s7_blast_targets/blast_reults/'            
#where this all will go
OUT_TAB=WRK+"s8_compile_data/"


#inport all the data

uniq_df = pd.read_csv(UNIQ_TAB, sep='\t', names=['output_uniq','cluster_num','member_num','output_size','input_first'])
parse_df = pd.read_csv(P_TABLE, sep='\t', names=['type','match'])
tax_df = pd.read_csv(TAX_TAB, sep='[\t|;]', names=['Kingdom','Phylum','Class','Order','Family','Genus','Species'])
# Out:
# /home/pd378/miniconda3/envs/jupyter_env/lib/python3.6/site-packages/ipykernel_launcher.py:22: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
#split up the uniq_df for easier reading
file_list=[]
size_list=[]
uniq_list=[]
for item in uniq_df.index:
    path=item.split("/")
    file_list.append(path[8].split(";")[0].strip('_ribo.fa'))
    size_list.append(path[8].rsplit(";")[2].strip('size='))
    uniq_list.append(path[8].split(";")[1])
uniq_df['file'] = file_list
uniq_df['in_size']=size_list
uniq_df['in_uniq']=uniq_list
uniq_df.sort_index


#update the parsed file to make more sense
index_list=[]
sample_list=[]
size_list=[]
otu_liste=[]
for item in parse_df.index:
    name=item.split(';')[0]
    index_list.append(name)
    size_list.append(item.split(';')[1].strip("size="))
    sample_list.append(name.split("_Uniq")[0])
   
parse_df.index = index_list
parse_df["size"]=size_list
parse_df["sample"]=sample_list



#parse through the ky table and pull out the otu name
#then use the otu to fetch the taxonomy from the tax_df
otu_list=[]
for row in parse_df.iterrows():
    otu = ""
    if re.findall("otu\d+", row[1][0]):
        otu = row[1][0]
    elif "chimera" in (row[1][0]) or "Chimera" in row[1][1]:
        otu = "chimera"
    else:
        otu = re.findall("otu\d+",row[1][1])[0]
    otu_list.append(otu)
    
parse_df["otu"]=otu_list

# merge the parse and taxa table together
key_df=pd.merge(parse_df, tax_df, left_on="otu", how='outer', right_on=tax_df.index)

# continue merging the parse_df and tax_df with the uniq_df
cross_df=pd.merge(key_df,uniq_df,left_on='sample',right_on='output_uniq', how='outer', indicator=True)

#clean up the resulting df 
clean_df=cross_df[['file', 'in_size','in_uniq','otu', 'Kingdom', 'Phylum', 'Class','Order', 'Family', 'Genus']]

#strip off the weight from the genus so we can consolidate results better

# %%
with open(F_LIST) as f:
    for line in f: 
        NAME = line.strip()
        b_tab=BLAST_TABS+NAME+'_target.blast'
        
        try:
            with open(b_tab) as fh:
                pass
        except IOError as e:
            print ("Unable to open blast table "+NAME)
            continue

        #modify the index names for the blast table 
        blast_df = pd.read_csv(b_tab, sep='\t', names=['p.ident','other','length','mismatch','gapopen','q.start','q.end','s.start','s.send','eval','bitscore','s.title'])
        index_list=[]
        for item in blast_df.index:
            index_list.append(item.strip(';'))
        blast_df.index=index_list

        #reformat the blast information so it's in a single cell
        blast_df['blast_summary']=blast_df['other'].astype(str)+";"+blast_df['length'].astype(str)+';'+blast_df['mismatch'].astype(str)+";"+blast_df['gapopen'].astype(str)+";"+blast_df['q.start'].astype(str)+";"+blast_df['q.end'].astype(str)+";"+blast_df['s.start'].astype(str)+";"+blast_df['s.send'].astype(str)+";"+blast_df['eval'].astype(str)
        uniq_list=[]
        size_list=[]
        genus_list=[]
        for item in blast_df.index:
            uniq_list.append(item.split(";")[0])
            size_list.append(item.split(";")[1].strip("size="))
        blast_df['blast_uniq']=uniq_list
        blast_df['blast_size']=size_list

        #clean up the table
        blast_clean=blast_df[['s.title','blast_summary','blast_uniq','blast_size']]
        blast_clean.rename(columns = {'s.title':'blast_hit'}, inplace = True)
        blast_clean["file"]=NAME
        
        #merge the taxa information with the blast information
        final_df=pd.merge(blast_clean, clean_df,left_on=['file', 'blast_uniq'], right_on=['file','in_uniq'], how='left' )
        
        #format and condens the final table for export
        final_df=final_df.fillna("0")
        final_df['in_size']=final_df['in_size'].astype(int)
        final_df['sum_size']=final_df.groupby(by=['Phylum', 'Class', 'Order','Family','Genus',"blast_hit"])["in_size"].transform(sum)
        reduce_df=final_df.drop_duplicates(subset=['Phylum', 'Class', 'Order','Family', 'Genus',"blast_hit"]).sort_values(by=['sum_size'],ascending=False)
        reduce_df=reduce_df.drop(['blast_uniq','in_uniq','blast_size','in_size'], axis=1)
        reduce_df.to_csv(OUT_TAB+NAME+"_combined_tab.txt", sep='\t')
# Out:
# Unable to open blast table 053-Single-B335-1_CTX-M-A
# Unable to open blast table 054-Single-B335-2_CTX-M-A
# Unable to open blast table 055-Single-B335-3_CTX-M-A
# Unable to open blast table 056-Single-NEG_CTX-M-A
# Unable to open blast table 057-Single-B335-1_TEM-A
# Unable to open blast table 058-Single-B335-2_TEM-A
# Unable to open blast table 059-Single-B335-3_TEM-A
# Unable to open blast table 060-Single-NEG_TEM-A
# Unable to open blast table 061-Single-B335-1_CTX-M-B
# Unable to open blast table 062-Single-B335-2_CTX-M-B
# Unable to open blast table 063-Single-B335-3_CTX-M-B
# Unable to open blast table 064-Single-NEG_CTX-M-B
# Unable to open blast table 065-Single-B335-1_TEM-B
# Unable to open blast table 066-Single-B335-2_TEM-B
# Unable to open blast table 067-Single-B335-3_TEM-B
# Unable to open blast table 068-Single-NEG_TEM-B
# Unable to open blast table 069-Single-B335-1_CTX-M-C
# Unable to open blast table 070-Single-B335-2_CTX-M-C
# Unable to open blast table 071-Single-B335-3_CTX-M-C
# Unable to open blast table 072-Single-NEG_CTX-M-C
# Unable to open blast table 073-Single-B335-1_TEM-C
# Unable to open blast table 074-Single-B335-2_TEM-C
# Unable to open blast table 075-Single-B335-3_TEM-C
# Unable to open blast table 076-Single-NEG_TEM-C
# Unable to open blast table 077-Single-B335-1_SHV-A
# Unable to open blast table 078-Single-B335-2_SHV-A
# Unable to open blast table 079-Single-B335-3_SHV-A
# Unable to open blast table 080-Single-NEG_SHV-A
# Unable to open blast table 081-Single-B335-1_Tn-ISE-A
# Unable to open blast table 082-Single-B335-2_Tn-ISE-A
# Unable to open blast table 083-Single-B335-3_Tn-ISE-A
# Unable to open blast table 084-Single-NEG_Tn-ISE-A
# Unable to open blast table 085-Single-B335-1_SHV-B
# Unable to open blast table 086-Single-B335-2_SHV-B
# Unable to open blast table 087-Single-B335-3_SHV-B
# Unable to open blast table 088-Single-NEG_SHV-B
# Unable to open blast table 089-Single-B335-1_Tn-ISE-B
# Unable to open blast table 090-Single-B335-2_Tn-ISE-B
# Unable to open blast table 091-Single-B335-3_Tn-ISE-B
# Unable to open blast table 092-Single-NEG_Tn-ISE-B
# Unable to open blast table 093-Single-B335-1_SHV-C
# Unable to open blast table 094-Single-B335-2_SHV-C
# Unable to open blast table 095-Single-B335-3_SHV-C
# Unable to open blast table 096-Single-NEG_SHV-C
# Unable to open blast table 097-TransP-B335-1_Tn-ISE-C
# Unable to open blast table 098-TransP-B335-2_Tn-ISE-C
# Unable to open blast table 099-TransP-B335-3_Tn-ISE-C
# Unable to open blast table 100-TransP-NEG_Tn-ISE-C
# Unable to open blast table 101-TransP-B335-1_Tn-Reso-A
# Unable to open blast table 102-TransP-B335-2_Tn-Reso-A
# Unable to open blast table 103-TransP-B335-3_Tn-Reso-A
# Unable to open blast table 104-TransP-NEG_Tn-Reso-A
# Unable to open blast table 105-TransP-B335-1_Tn-Tran-A
# Unable to open blast table 106-TransP-B335-2_Tn-Tran-A
# Unable to open blast table 107-TransP-B335-3_Tn-Tran-A
# Unable to open blast table 108-TransP-NEG_Tn-Tran-A
# Unable to open blast table 109-TransP-B335-1_Tn-Reso-B
# Unable to open blast table 110-TransP-B335-2_Tn-Reso-B
# Unable to open blast table 111-TransP-B335-3_Tn-Reso-B
# Unable to open blast table 112-TransP-NEG_Tn-Reso-B
# Unable to open blast table 113-TransP-B335-1_Tn-Tran-B
# Unable to open blast table 114-TransP-B335-2_Tn-Tran-B
# Unable to open blast table 115-TransP-B335-3_Tn-Tran-B
# Unable to open blast table 116-TransP-NEG_Tn-Tran-B
# Unable to open blast table 117-TransP-B335-1_Tn-Reso-C
# Unable to open blast table 118-TransP-B335-2_Tn-Reso-C
# Unable to open blast table 119-TransP-B335-3_Tn-Reso-C
# Unable to open blast table 120-TransP-NEG_Tn-Reso-C
# Unable to open blast table 121-TransP-B335-1_Tn-Tran-C
# Unable to open blast table 122-TransP-B335-2_Tn-Tran-C
# Unable to open blast table 123-TransP-B335-3_Tn-Tran-C
# Unable to open blast table 124-TransP-NEG_Tn-Tran-C
# Unable to open blast table 125-Romb-B335-1_Romb-A
# Unable to open blast table 126-Romb-B335-2_Romb-A
# Unable to open blast table 127-Romb-B335-3_Romb-A
# Unable to open blast table 128-Romb-NEG_Romb-A
# Unable to open blast table 129-Romb-B335-1_Romb-B
# Unable to open blast table 130-Romb-B335-2_Romb-B
# Unable to open blast table 131-Romb-B335-3_Romb-B
# Unable to open blast table 132-Romb-NEG_Romb-B
# Unable to open blast table 133-Romb-B335-1_Romb-C
# Unable to open blast table 134-Romb-B335-2_Romb-C
# Unable to open blast table 135-Romb-B335-3_Romb-C
# Unable to open blast table 136-Romb-NEG_Romb-C
# Unable to open blast table 137-Single-CTX-NEG-A
# Unable to open blast table 138-Single-TEM-NEG-A
# Unable to open blast table 139-Single-SHV-NEG-A
# Unable to open blast table 140-TransP-ISE-NEG-A
# Unable to open blast table 141-TransP-Reso-NEG-A
# Unable to open blast table 142-TransP-Tran-NEG-A
# Unable to open blast table 143-Romb-Romb-NEG-A
# /home/pd378/.local/lib/python3.6/site-packages/pandas/core/frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /home/pd378/miniconda3/envs/jupyter_env/lib/python3.6/site-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Unable to open blast table 005-B313_1-CTX
# Unable to open blast table 006-B313_1-CTX
# Unable to open blast table 007-B313_1-CTX
# Unable to open blast table 008-B313_1-CTX
# Unable to open blast table 009-B313_1-SHV
# Unable to open blast table 010-B313_1-SHV
# Unable to open blast table 011-B313_1-SHV
# Unable to open blast table 012-B313_1-SHV
# Unable to open blast table 013-B313_1-TEM
# Unable to open blast table 014-B313_1-TEM
# Unable to open blast table 015-B313_1-TEM
# Unable to open blast table 016-B313_1-TEM
# Unable to open blast table 021-B314_2-CTX
# Unable to open blast table 022-B314_2-CTX
# Unable to open blast table 023-B314_2-CTX
# Unable to open blast table 024-B314_2-CTX
# Unable to open blast table 025-B314_2-SHV
# Unable to open blast table 026-B314_2-SHV
# Unable to open blast table 027-B314_2-SHV
# Unable to open blast table 028-B314_2-SHV
# Unable to open blast table 029-B314_2-TEM
# Unable to open blast table 030-B314_2-TEM
# Unable to open blast table 031-B314_2-TEM
# Unable to open blast table 032-B314_2-TEM
# Unable to open blast table 037-B335_1-CTX
# Unable to open blast table 038-B335_1-CTX
# Unable to open blast table 039-B335_1-CTX
# Unable to open blast table 040-B335_1-CTX
# Unable to open blast table 041-B335_1-SHV
# Unable to open blast table 042-B335_1-SHV
# Unable to open blast table 043-B335_1-SHV
# Unable to open blast table 044-B335_1-SHV
# Unable to open blast table 045-B335_1-TEM
# Unable to open blast table 046-B335_1-TEM
# Unable to open blast table 047-B335_1-TEM
# Unable to open blast table 048-B335_1-TEM
# Unable to open blast table 053-B335_2-CTX
# Unable to open blast table 054-B335_2-CTX
# Unable to open blast table 055-B335_2-CTX
# Unable to open blast table 056-B335_2-CTX
# Unable to open blast table 057-B335_2-SHV
# Unable to open blast table 058-B335_2-SHV
# Unable to open blast table 059-B335_2-SHV
# Unable to open blast table 060-B335_2-SHV
# Unable to open blast table 061-B335_2-TEM
# Unable to open blast table 062-B335_2-TEM
# Unable to open blast table 063-B335_2-TEM
# Unable to open blast table 064-B335_2-TEM
# Unable to open blast table 069-B335_3-CTX
# Unable to open blast table 070-B335_3-CTX
# Unable to open blast table 071-B335_3-CTX
# Unable to open blast table 072-B335_3-CTX
# Unable to open blast table 073-B335_3-SHV
# Unable to open blast table 074-B335_3-SHV
# Unable to open blast table 075-B335_3-SHV
# Unable to open blast table 076-B335_3-SHV
# Unable to open blast table 077-B335_3-TEM
# Unable to open blast table 078-B335_3-TEM
# Unable to open blast table 079-B335_3-TEM
# Unable to open blast table 080-B335_3-TEM
# Unable to open blast table 091-R1_NEG-CTX
# Unable to open blast table 092-R1_NEG-CTX
# Unable to open blast table 093-R1_NEG-CTX
# Unable to open blast table 094-R1_NEG-CTX
# Unable to open blast table 095-R1_NEG-SHV
# Unable to open blast table 096-R1_NEG-SHV
# Unable to open blast table 097-R1_NEG-SHV
# Unable to open blast table 098-R1_NEG-SHV
# Unable to open blast table 099-R1_NEG-TEM
# Unable to open blast table 100-R1_NEG-TEM
# Unable to open blast table 101-R1_NEG-TEM
# Unable to open blast table 102-R1_NEG-TEM
# Unable to open blast table 104-R2_NEG-CTX
# Unable to open blast table 105-R2_NEG-SHV
# Unable to open blast table 106-R2_NEG-TEM
# Unable to open blast table 112-UC02_Spike-CTX
# Unable to open blast table 113-UC02_Spike-CTX
# Unable to open blast table 114-UC02_Spike-CTX
# Unable to open blast table 115-UC02_Spike-CTX
# Unable to open blast table 116-UC02_Spike-SHV
# Unable to open blast table 117-UC02_Spike-SHV
# Unable to open blast table 118-UC02_Spike-SHV
# Unable to open blast table 119-UC02_Spike-SHV
# Unable to open blast table 120-UC02_Spike-TEM
# Unable to open blast table 121-UC02_Spike-TEM
# Unable to open blast table 122-UC02_Spike-TEM
# Unable to open blast table 123-UC02_Spike-TEM
# Unable to open blast table 128-UC02_Spike-CTX
# Unable to open blast table 129-UC02_Spike-CTX
# Unable to open blast table 130-UC02_Spike-CTX
# Unable to open blast table 131-UC02_Spike-CTX
# Unable to open blast table 132-UC02_Spike-SHV
# Unable to open blast table 133-UC02_Spike-SHV
# Unable to open blast table 134-UC02_Spike-SHV
# Unable to open blast table 135-UC02_Spike-SHV
# Unable to open blast table 136-UC02_Spike-TEM
# Unable to open blast table 137-UC02_Spike-TEM
# Unable to open blast table 138-UC02_Spike-TEM
# Unable to open blast table 139-UC02_Spike-TEM
# Unable to open blast table 073-spike-H01-0p
# Unable to open blast table 074-spike-H01-0-1p
# Unable to open blast table 075-spike-H01-1p
# Unable to open blast table 076-spike-H01-10p
# Unable to open blast table 077-spike-H02-0p
# Unable to open blast table 078-spike-H02-0-1p
# Unable to open blast table 079-spike-H02-1p
# Unable to open blast table 080-spike-H02-10p
# Unable to open blast table 081-spike-H01-0p
# Unable to open blast table 082-spike-H01-0-1p
# Unable to open blast table 083-spike-H01-1p
# Unable to open blast table 084-spike-H01-10p
# Unable to open blast table 085-spike-H02-0p
# Unable to open blast table 086-spike-H02-0-1p
# Unable to open blast table 087-spike-H02-1p
# Unable to open blast table 088-spike-H02-10p
# Unable to open blast table 089-spike-H01-0p
# Unable to open blast table 090-spike-H01-0-1p
# Unable to open blast table 091-spike-H01-1p
# Unable to open blast table 092-spike-H01-10p
# Unable to open blast table 093-spike-H02-0p
# Unable to open blast table 094-spike-H02-0-1p
# Unable to open blast table 095-spike-H02-1p
# Unable to open blast table 096-spike-H02-10p
# Unable to open blast table 097-spike-C02-0p
# Unable to open blast table 098-spike-C02-0-1p
# Unable to open blast table 099-spike-C02-1p
# Unable to open blast table 100-spike-C02-10p
# Unable to open blast table 102-spike-NEG-R1
# Unable to open blast table 103-spike-H01-pSpike
# Unable to open blast table 104-spike-NEG-R2
# Unable to open blast table 105-spike-C02-0p
# Unable to open blast table 106-spike-C02-0-1p
# Unable to open blast table 107-spike-C02-1p
# Unable to open blast table 108-spike-C02-10p
# Unable to open blast table 110-spike-NEG-R1
# Unable to open blast table 111-spike-H02-pSpike
# Unable to open blast table 112-spike-NEG-R2
# Unable to open blast table 113-spike-C02-0p
# Unable to open blast table 114-spike-C02-0-1p
# Unable to open blast table 115-spike-C02-1p
# Unable to open blast table 116-spike-C02-10p
# Unable to open blast table 118-spike-NEG-R1
# Unable to open blast table 119-spike-C02-pSpike
# Unable to open blast table 142-Taxa-C02-vulg

# %%
#004-B313_1-Bact_target.blast
blast_df = pd.read_csv(BLAST_TABS+'004-B313_1-Bact_target.blast', sep='\t', names=['p.ident','other','length','mismatch','gapopen','q.start','q.end','s.start','s.send','eval','bitscore','s.title'])

# %%
blast_df
# Out:
#                                        p.ident    other  length  mismatch  \
# Uniq1;size=890;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq2;size=865;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq3;size=331;    gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq4;size=295;    gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq5;size=214;    gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq6;size=211;    gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq7;size=141;    gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq8;size=135;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq9;size=127;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq10;size=97;    gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq11;size=74;    gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq12;size=65;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq13;size=64;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq14;size=59;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq15;size=59;    gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq16;size=57;    gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq17;size=55;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq18;size=54;    gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq19;size=49;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq20;size=48;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq21;size=47;    gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq22;size=45;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq23;size=45;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq24;size=41;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq25;size=40;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq26;size=39;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq27;size=39;    gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq28;size=38;    gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq29;size=37;   gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq30;size=34;    gi|938475369|gb|CP012937.1|  100.000     106         0
# ...                                        ...      ...     ...       ...
# Uniq2963;size=1;   gi|938475369|gb|CP012937.1|   99.057     106         1
# Uniq2964;size=1;  gi|1042799677|gb|CP012706.1|   99.048     105         1
# Uniq2965;size=1;  gi|1042799677|gb|CP012706.1|  100.000     105         0
# Uniq2966;size=1;  gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq2967;size=1;   gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq2968;size=1;  gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq2969;size=1;  gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq2970;size=1;  gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq2971;size=1;   gi|938475369|gb|CP012937.1|   98.113     106         2
# Uniq2972;size=1;  gi|1042799677|gb|CP012706.1|   96.939      98         3
# Uniq2973;size=1;  gi|1042799677|gb|CP012706.1|   99.057     106         1
# Uniq2974;size=1;   gi|938475369|gb|CP012937.1|   98.113     106         2
# Uniq2975;size=1;  gi|1042799677|gb|CP012706.1|   98.095     105         2
# Uniq2976;size=1;  gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq2977;size=1;  gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq2978;size=1;  gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq2979;size=1;  gi|1042799677|gb|CP012706.1|   99.057     106         1
# Uniq2980;size=1;  gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq2981;size=1;  gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq2982;size=1;   gi|938475369|gb|CP012937.1|   99.057     106         1
# Uniq2983;size=1;  gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq2984;size=1;   gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq2985;size=1;   gi|938475369|gb|CP012937.1|   99.057     106         1
# Uniq2986;size=1;   gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq2987;size=1;  gi|1042799677|gb|CP012706.1|   94.340     106         6
# Uniq2988;size=1;   gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq2989;size=1;   gi|938475369|gb|CP012937.1|  100.000     106         0
# Uniq2990;size=1;   gi|938475369|gb|CP012937.1|  100.000     105         0
# Uniq2991;size=1;  gi|1042799677|gb|CP012706.1|  100.000     106         0
# Uniq2992;size=1;   gi|938475369|gb|CP012937.1|   94.340     106         6
#
#                   gapopen  q.start  q.end  s.start   s.send          eval  \
# Uniq1;size=890;         0        1    106  3816568  3816463  7.230000e-47
# Uniq2;size=865;         0        1    106  3816568  3816463  7.230000e-47
# Uniq3;size=331;         0        1    106   505683   505788  7.230000e-47
# Uniq4;size=295;         0        1    106   505683   505788  7.230000e-47
# Uniq5;size=214;         0        1    106   505683   505788  7.230000e-47
# Uniq6;size=211;         0        1    106   505683   505788  7.230000e-47
# Uniq7;size=141;         0        1    106   505683   505788  7.230000e-47
# Uniq8;size=135;         0        1    106  3816568  3816463  7.230000e-47
# Uniq9;size=127;         0        1    106  3816568  3816463  7.230000e-47
# Uniq10;size=97;         0        1    106   505683   505788  7.230000e-47
# Uniq11;size=74;         0        1    106   505683   505788  7.230000e-47
# Uniq12;size=65;         0        1    106  3816568  3816463  7.230000e-47
# Uniq13;size=64;         0        1    106  3816568  3816463  7.230000e-47
# Uniq14;size=59;         0        1    106  3816568  3816463  7.230000e-47
# Uniq15;size=59;         0        1    106   505683   505788  7.230000e-47
# Uniq16;size=57;         0        1    106   505683   505788  7.230000e-47
# Uniq17;size=55;         0        1    106  3816568  3816463  7.230000e-47
# Uniq18;size=54;         0        1    106   505683   505788  7.230000e-47
# Uniq19;size=49;         0        1    106  3816568  3816463  7.230000e-47
# Uniq20;size=48;         0        1    106  3816568  3816463  7.230000e-47
# Uniq21;size=47;         0        1    106   505683   505788  7.230000e-47
# Uniq22;size=45;         0        1    106  3816568  3816463  7.230000e-47
# Uniq23;size=45;         0        1    106  3816568  3816463  7.230000e-47
# Uniq24;size=41;         0        1    106  3816568  3816463  7.230000e-47
# Uniq25;size=40;         0        1    106  3816568  3816463  7.230000e-47
# Uniq26;size=39;         0        1    106  3816568  3816463  7.230000e-47
# Uniq27;size=39;         0        1    106   505683   505788  7.230000e-47
# Uniq28;size=38;         0        1    106   505683   505788  7.230000e-47
# Uniq29;size=37;         0        1    106  3816568  3816463  7.230000e-47
# Uniq30;size=34;         0        1    106   505683   505788  7.230000e-47
# ...                   ...      ...    ...      ...      ...           ...
# Uniq2963;size=1;        0        1    106   505683   505788  3.360000e-45
# Uniq2964;size=1;        0        1    105  3816568  3816464  1.210000e-44
# Uniq2965;size=1;        0        1    105  3816567  3816463  2.560000e-46
# Uniq2966;size=1;        0        1    106  3816568  3816463  7.230000e-47
# Uniq2967;size=1;        0        1    106   505683   505788  7.230000e-47
# Uniq2968;size=1;        0        1    106  3816568  3816463  7.230000e-47
# Uniq2969;size=1;        0        1    106  3816568  3816463  7.230000e-47
# Uniq2970;size=1;        0        1    106  3816568  3816463  7.230000e-47
# Uniq2971;size=1;        0        1    106   505683   505788  1.560000e-43
# Uniq2972;size=1;        0        9    106  3816560  3816463  2.040000e-37
# Uniq2973;size=1;        0        1    106  3816568  3816463  3.360000e-45
# Uniq2974;size=1;        0        1    106   505683   505788  1.560000e-43
# Uniq2975;size=1;        0        1    105  3816568  3816464  5.630000e-43
# Uniq2976;size=1;        0        1    106  3816568  3816463  7.230000e-47
# Uniq2977;size=1;        0        1    106  3816568  3816463  7.230000e-47
# Uniq2978;size=1;        0        1    106  3816568  3816463  7.230000e-47
# Uniq2979;size=1;        0        1    106  3816568  3816463  3.360000e-45
# Uniq2980;size=1;        0        1    106  3816568  3816463  7.230000e-47
# Uniq2981;size=1;        0        1    106  3816568  3816463  7.230000e-47
# Uniq2982;size=1;        0        1    106   505683   505788  3.360000e-45
# Uniq2983;size=1;        0        1    106  3816568  3816463  7.230000e-47
# Uniq2984;size=1;        0        1    106   505683   505788  7.230000e-47
# Uniq2985;size=1;        0        1    106   505683   505788  3.360000e-45
# Uniq2986;size=1;        0        1    106   505683   505788  7.230000e-47
# Uniq2987;size=1;        0        1    106  3816568  3816463  7.330000e-37
# Uniq2988;size=1;        0        1    106   505683   505788  7.230000e-47
# Uniq2989;size=1;        0        1    106   505683   505788  7.230000e-47
# Uniq2990;size=1;        0        1    105   505684   505788  2.560000e-46
# Uniq2991;size=1;        0        1    106  3816568  3816463  7.230000e-47
# Uniq2992;size=1;        0        1    106   505683   505788  7.330000e-37
#
#                   bitscore                                            s.title
# Uniq1;size=890;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq2;size=865;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq3;size=331;      196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq4;size=295;      196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq5;size=214;      196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq6;size=211;      196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq7;size=141;      196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq8;size=135;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq9;size=127;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq10;size=97;      196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq11;size=74;      196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq12;size=65;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq13;size=64;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq14;size=59;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq15;size=59;      196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq16;size=57;      196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq17;size=55;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq18;size=54;      196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq19;size=49;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq20;size=48;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq21;size=47;      196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq22;size=45;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq23;size=45;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq24;size=41;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq25;size=40;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq26;size=39;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq27;size=39;      196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq28;size=38;      196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq29;size=37;      196.0   Bacteroides fragilis strain S14, complete genome
# Uniq30;size=34;      196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# ...                    ...                                                ...
# Uniq2963;size=1;     191.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq2964;size=1;     189.0   Bacteroides fragilis strain S14, complete genome
# Uniq2965;size=1;     195.0   Bacteroides fragilis strain S14, complete genome
# Uniq2966;size=1;     196.0   Bacteroides fragilis strain S14, complete genome
# Uniq2967;size=1;     196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq2968;size=1;     196.0   Bacteroides fragilis strain S14, complete genome
# Uniq2969;size=1;     196.0   Bacteroides fragilis strain S14, complete genome
# Uniq2970;size=1;     196.0   Bacteroides fragilis strain S14, complete genome
# Uniq2971;size=1;     185.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq2972;size=1;     165.0   Bacteroides fragilis strain S14, complete genome
# Uniq2973;size=1;     191.0   Bacteroides fragilis strain S14, complete genome
# Uniq2974;size=1;     185.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq2975;size=1;     183.0   Bacteroides fragilis strain S14, complete genome
# Uniq2976;size=1;     196.0   Bacteroides fragilis strain S14, complete genome
# Uniq2977;size=1;     196.0   Bacteroides fragilis strain S14, complete genome
# Uniq2978;size=1;     196.0   Bacteroides fragilis strain S14, complete genome
# Uniq2979;size=1;     191.0   Bacteroides fragilis strain S14, complete genome
# Uniq2980;size=1;     196.0   Bacteroides fragilis strain S14, complete genome
# Uniq2981;size=1;     196.0   Bacteroides fragilis strain S14, complete genome
# Uniq2982;size=1;     191.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq2983;size=1;     196.0   Bacteroides fragilis strain S14, complete genome
# Uniq2984;size=1;     196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq2985;size=1;     191.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq2986;size=1;     196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq2987;size=1;     163.0   Bacteroides fragilis strain S14, complete genome
# Uniq2988;size=1;     196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq2989;size=1;     196.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq2990;size=1;     195.0  Bacteroides thetaiotaomicron strain 7330, comp...
# Uniq2991;size=1;     196.0   Bacteroides fragilis strain S14, complete genome
# Uniq2992;size=1;     163.0  Bacteroides thetaiotaomicron strain 7330, comp...
#
# [2991 rows x 12 columns]

# %%
NAME
# Out:
# '146-Taxa-NR2-Prev10'
