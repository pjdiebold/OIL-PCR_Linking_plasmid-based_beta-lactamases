# %%
from glob import glob
from tqdm import tqdm
import subprocess
import pandas as pd
import natsort as ns
import numpy as np
import os
import re

# %%
#Define my directories and location of files
WRK = '/workdir/users/pd378/oilPCR/bulk_process_all_OIL_for_paper/'

F_LIST = WRK+'file_lists/filelist.txt' #a list of the files used for iterating and namings6

#This table connects the second round of uniq reads witht he first round sample specific uniqs
UNIQ_TAB=WRK+"s6_cluster_otu/filtered_uniqs/combined_uniq_tab.txt"
#the parsed tabels generated from the usearch otu clustering 
P_TABLE=WRK+'s6_cluster_otu/filtered_uniqs/uniq_parsed_otu_tab.txt'
#The table of taxonomy generated from using mother to assign taxonomy
TAX_TAB=WRK+'s6_cluster_otu/filtered_uniqs/uniq_clustered_otus.V4_oil.wang.taxonomy' 
#the blast table generated from blasting the targets
BLAST_TABS=WRK+'s7_blast_targets/blast_reults/'            
#where this all will go
OUT_TAB=WRK+"s8_compile_data/"


#inport all the data

uniq_df = pd.read_csv(UNIQ_TAB, sep='\t', names=['output_uniq','cluster_num','member_num','output_size','input_first'])
parse_df = pd.read_csv(P_TABLE, sep='\t', names=['type','match'])
tax_df = pd.read_csv(TAX_TAB, sep='[\t|;]', names=['Kingdom','Phylum','Class','Order','Family','Genus','Species'])
# Out:
# /home/pd378/miniconda3/envs/jupyter_env/lib/python3.6/site-packages/ipykernel_launcher.py:22: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
#split up the uniq_df for easier reading
file_list=[]
size_list=[]
uniq_list=[]
for item in uniq_df.index:
    path=item.split("/")
    file_list.append(path[8].split(";")[0].strip('_ribo.fa'))
    size_list.append(path[8].rsplit(";")[2].strip('size='))
    uniq_list.append(path[8].split(";")[1])
uniq_df['file'] = file_list
uniq_df['in_size']=size_list
uniq_df['in_uniq']=uniq_list
uniq_df.sort_index


#update the parsed file to make more sense
index_list=[]
sample_list=[]
size_list=[]
otu_liste=[]
for item in parse_df.index:
    name=item.split(';')[0]
    index_list.append(name)
    size_list.append(item.split(';')[1].strip("size="))
    sample_list.append(name.split("_Uniq")[0])
   
parse_df.index = index_list
parse_df["size"]=size_list
parse_df["sample"]=sample_list



#parse through the ky table and pull out the otu name
#then use the otu to fetch the taxonomy from the tax_df
otu_list=[]
for row in parse_df.iterrows():
    otu = ""
    if re.findall("otu\d+", row[1][0]):
        otu = row[1][0]
    elif "chimera" in (row[1][0]) or "Chimera" in row[1][1]:
        otu = "chimera"
    else:
        otu = re.findall("otu\d+",row[1][1])[0]
    otu_list.append(otu)
    
parse_df["otu"]=otu_list

# merge the parse and taxa table together
key_df=pd.merge(parse_df, tax_df, left_on="otu", how='outer', right_on=tax_df.index)

# continue merging the parse_df and tax_df with the uniq_df
cross_df=pd.merge(key_df,uniq_df,left_on='sample',right_on='output_uniq', how='outer', indicator=True)

#clean up the resulting df 
clean_df=cross_df[['file', 'in_size','in_uniq','otu', 'Kingdom', 'Phylum', 'Class','Order', 'Family', 'Genus']]

#strip off the weight from the genus so we can consolidate results better

# %%
#begin looping through blast files
with open(F_LIST) as f:
    for line in f: 
        NAME = line.strip()
        b_tab=BLAST_TABS+NAME+'_targ.blast'
        
        try:
            with open(b_tab) as fh:
                pass
        except IOError as e:
            print ("Unable to open blast table "+NAME)
            continue

        #modify the index names for the blast table 
        blast_df = pd.read_csv(b_tab, sep='\t', names=['p.ident','length','mismatch','gapopen','q.start','q.end','s.start','s.send','eval','bitscore','s.title'])
        index_list=[]
        for item in blast_df.index:
            index_list.append(item.strip(';'))
        blast_df.index=index_list

        #reformat the blast information so it's in a single cell
        blast_df['blast_summary']=blast_df['length'].astype(str)+';'+blast_df['mismatch'].astype(str)+";"+blast_df['gapopen'].astype(str)+";"+blast_df['q.start'].astype(str)+";"+blast_df['q.end'].astype(str)+";"+blast_df['s.start'].astype(str)+";"+blast_df['s.send'].astype(str)+";"+blast_df['eval'].astype(str)+";"+blast_df['bitscore'].astype(str)
        uniq_list=[]
        size_list=[]
        genus_list=[]
        for item in blast_df.index:
            uniq_list.append(item.split(";")[0])
            size_list.append(item.split(";")[1].strip("size="))
        blast_df['blast_uniq']=uniq_list
        blast_df['blast_size']=size_list

        #clean up the table
        blast_clean=blast_df[['p.ident','blast_summary','blast_uniq','blast_size']]
        blast_clean.rename(columns = {'p.ident':'blast_hit'}, inplace = True)
        blast_clean["file"]=NAME
        
        #merge the taxa information with the blast information
        final_df=pd.merge(blast_clean, clean_df,left_on=['file', 'blast_uniq'], right_on=['file','in_uniq'], how='left' )
        
        #format and condens the final table for export
        final_df=final_df.fillna("0")
        final_df['in_size']=final_df['in_size'].astype(int)
        final_df['sum_size']=final_df.groupby(by=['Phylum', 'Class', 'Order','Family','Genus',"blast_hit"])["in_size"].transform(sum)
        reduce_df=final_df.drop_duplicates(subset=['Phylum', 'Class', 'Order','Family', 'Genus',"blast_hit"]).sort_values(by=['sum_size'],ascending=False)
        reduce_df=reduce_df.drop(['blast_uniq','in_uniq','blast_size','in_size'], axis=1)
        reduce_df.to_csv(OUT_TAB+NAME+"_combined_tab.txt", sep='\t')
# Out:
# /home/pd378/.local/lib/python3.6/site-packages/pandas/core/frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
# /home/pd378/miniconda3/envs/jupyter_env/lib/python3.6/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
NAME
# Out:
# '086-spike-H02-0-1p'

# %%
final_df
# Out:
#      blast_hit                            blast_summary blast_uniq blast_size  \
# 0          CmR                73;0;0;5;77;1;73;2.08e-39      Uniq1      19606
# 1          CmR                73;0;0;5;77;1;73;2.08e-39      Uniq2      12713
# 2          CmR                73;0;0;5;77;1;73;2.08e-39      Uniq3       1537
# 3          CmR                73;0;0;5;77;1;73;2.08e-39      Uniq4       1039
# 4          CmR                73;0;0;5;77;1;73;2.08e-39      Uniq5        804
# 5          CmR                73;0;0;5;77;1;73;2.08e-39      Uniq6        681
# 6          CmR                73;0;0;5;77;1;73;2.08e-39      Uniq7        502
# 7          CmR                73;0;0;5;77;1;73;2.08e-39      Uniq8        432
# 8          CmR                73;0;0;5;77;1;73;2.08e-39      Uniq9        420
# 9          CmR                73;0;0;5;77;1;73;2.08e-39     Uniq10        371
# 10         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq11        359
# 11         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq12        319
# 12         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq13        286
# 13         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq14        238
# 14         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq15        222
# 15         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq16        210
# 16         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq18        167
# 17         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq19        164
# 18         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq20        163
# 19         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq21        136
# 20         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq22        127
# 21         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq23        116
# 22         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq24        111
# 23         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq25        108
# 24         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq26        106
# 25         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq27        103
# 26         CmR                73;0;0;4;76;1;73;2.05e-39     Uniq28        100
# 27         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq29         94
# 28         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq30         87
# 29         CmR                73;0;0;5;77;1;73;2.08e-39     Uniq31         84
# ...        ...                                      ...        ...        ...
# 7887       CmR  73;1;0;5;77;1;73;5.0699999999999995e-37   Uniq8240          1
# 7888       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8243          1
# 7889       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8244          1
# 7890       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8245          1
# 7891       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8246          1
# 7892       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8247          1
# 7893       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8248          1
# 7894       CmR                71;3;0;7;77;3;73;4.71e-31   Uniq8249          1
# 7895       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8250          1
# 7896       CmR  73;1;0;5;77;1;73;5.0699999999999995e-37   Uniq8251          1
# 7897       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8252          1
# 7898       CmR  73;1;0;5;77;1;73;5.0699999999999995e-37   Uniq8253          1
# 7899       CmR  73;1;0;5;77;1;73;5.0699999999999995e-37   Uniq8254          1
# 7900       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8255          1
# 7901       CmR                   73;1;0;4;76;1;73;5e-37   Uniq8256          1
# 7902       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8258          1
# 7903       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8259          1
# 7904       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8260          1
# 7905       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8261          1
# 7906       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8262          1
# 7907       CmR  73;1;0;5;77;1;73;5.0699999999999995e-37   Uniq8263          1
# 7908       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8264          1
# 7909       CmR  73;1;0;5;77;1;73;5.0699999999999995e-37   Uniq8265          1
# 7910       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8266          1
# 7911       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8267          1
# 7912       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8268          1
# 7913       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8269          1
# 7914       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8270          1
# 7915       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8271          1
# 7916       CmR                73;0;0;5;77;1;73;2.08e-39   Uniq8272          1
#
#                     file in_size   in_uniq     otu        Kingdom  \
# 0     086-spike-H02-0-1p   19606     Uniq1    otu2  Bacteria(100)
# 1     086-spike-H02-0-1p   12713     Uniq2    otu2  Bacteria(100)
# 2     086-spike-H02-0-1p    1537     Uniq3    otu2  Bacteria(100)
# 3     086-spike-H02-0-1p    1039     Uniq4    otu2  Bacteria(100)
# 4     086-spike-H02-0-1p     804     Uniq5    otu2  Bacteria(100)
# 5     086-spike-H02-0-1p     681     Uniq6    otu2  Bacteria(100)
# 6     086-spike-H02-0-1p     502     Uniq7    otu2  Bacteria(100)
# 7     086-spike-H02-0-1p     432     Uniq8    otu2  Bacteria(100)
# 8     086-spike-H02-0-1p     420     Uniq9    otu2  Bacteria(100)
# 9     086-spike-H02-0-1p     371    Uniq10    otu2  Bacteria(100)
# 10    086-spike-H02-0-1p     359    Uniq11    otu2  Bacteria(100)
# 11    086-spike-H02-0-1p     319    Uniq12    otu2  Bacteria(100)
# 12    086-spike-H02-0-1p     286    Uniq13    otu2  Bacteria(100)
# 13    086-spike-H02-0-1p     238    Uniq14    otu2  Bacteria(100)
# 14    086-spike-H02-0-1p     222    Uniq15    otu2  Bacteria(100)
# 15    086-spike-H02-0-1p     210    Uniq16    otu2  Bacteria(100)
# 16    086-spike-H02-0-1p     167    Uniq18    otu2  Bacteria(100)
# 17    086-spike-H02-0-1p     164    Uniq19    otu2  Bacteria(100)
# 18    086-spike-H02-0-1p     163    Uniq20    otu2  Bacteria(100)
# 19    086-spike-H02-0-1p     136    Uniq21    otu2  Bacteria(100)
# 20    086-spike-H02-0-1p     127    Uniq22    otu2  Bacteria(100)
# 21    086-spike-H02-0-1p     116    Uniq23    otu2  Bacteria(100)
# 22    086-spike-H02-0-1p     111    Uniq24    otu2  Bacteria(100)
# 23    086-spike-H02-0-1p     108    Uniq25    otu2  Bacteria(100)
# 24    086-spike-H02-0-1p     106    Uniq26    otu2  Bacteria(100)
# 25    086-spike-H02-0-1p     103    Uniq27    otu2  Bacteria(100)
# 26    086-spike-H02-0-1p     100    Uniq28    otu2  Bacteria(100)
# 27    086-spike-H02-0-1p      94    Uniq29    otu2  Bacteria(100)
# 28    086-spike-H02-0-1p      87    Uniq30    otu2  Bacteria(100)
# 29    086-spike-H02-0-1p      84    Uniq31    otu2  Bacteria(100)
# ...                  ...     ...       ...     ...            ...
# 7887  086-spike-H02-0-1p       1  Uniq8240    otu2  Bacteria(100)
# 7888  086-spike-H02-0-1p       1  Uniq8243    otu2  Bacteria(100)
# 7889  086-spike-H02-0-1p       1  Uniq8244    otu2  Bacteria(100)
# 7890  086-spike-H02-0-1p       1  Uniq8245    otu2  Bacteria(100)
# 7891  086-spike-H02-0-1p       1  Uniq8246    otu2  Bacteria(100)
# 7892  086-spike-H02-0-1p       1  Uniq8247    otu2  Bacteria(100)
# 7893  086-spike-H02-0-1p       1  Uniq8248    otu2  Bacteria(100)
# 7894  086-spike-H02-0-1p       1  Uniq8249    otu2  Bacteria(100)
# 7895  086-spike-H02-0-1p       1  Uniq8250   otu49  Bacteria(100)
# 7896  086-spike-H02-0-1p       1  Uniq8251    otu2  Bacteria(100)
# 7897  086-spike-H02-0-1p       1  Uniq8252    otu2  Bacteria(100)
# 7898  086-spike-H02-0-1p       1  Uniq8253    otu2  Bacteria(100)
# 7899  086-spike-H02-0-1p       1  Uniq8254    otu2  Bacteria(100)
# 7900  086-spike-H02-0-1p       1  Uniq8255    otu2  Bacteria(100)
# 7901  086-spike-H02-0-1p       1  Uniq8256    otu2  Bacteria(100)
# 7902  086-spike-H02-0-1p       1  Uniq8258    otu2  Bacteria(100)
# 7903  086-spike-H02-0-1p       1  Uniq8259    otu2  Bacteria(100)
# 7904  086-spike-H02-0-1p       1  Uniq8260  otu307  Bacteria(100)
# 7905  086-spike-H02-0-1p       1  Uniq8261    otu2  Bacteria(100)
# 7906  086-spike-H02-0-1p       1  Uniq8262    otu2  Bacteria(100)
# 7907  086-spike-H02-0-1p       1  Uniq8263    otu2  Bacteria(100)
# 7908  086-spike-H02-0-1p       1  Uniq8264    otu2  Bacteria(100)
# 7909  086-spike-H02-0-1p       1  Uniq8265    otu2  Bacteria(100)
# 7910  086-spike-H02-0-1p       1  Uniq8266    otu2  Bacteria(100)
# 7911  086-spike-H02-0-1p       1  Uniq8267    otu2  Bacteria(100)
# 7912  086-spike-H02-0-1p       1  Uniq8268    otu2  Bacteria(100)
# 7913  086-spike-H02-0-1p       1  Uniq8269    otu2  Bacteria(100)
# 7914  086-spike-H02-0-1p       1  Uniq8270    otu2  Bacteria(100)
# 7915  086-spike-H02-0-1p       1  Uniq8271    otu2  Bacteria(100)
# 7916  086-spike-H02-0-1p       1  Uniq8272    otu2  Bacteria(100)
#
#                    Phylum                     Class                   Order  \
# 0     Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 1     Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 2     Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 3     Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 4     Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 5     Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 6     Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7     Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 8     Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 9     Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 10    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 11    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 12    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 13    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 14    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 15    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 16    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 17    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 18    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 19    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 20    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 21    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 22    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 23    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 24    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 25    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 26    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 27    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 28    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 29    Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# ...                   ...                       ...                     ...
# 7887  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7888  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7889  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7890  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7891  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7892  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7893  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7894  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7895  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7896  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7897  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7898  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7899  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7900  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7901  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7902  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7903  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7904   Proteobacteria(99)   Gammaproteobacteria(99)   Enterobacteriales(99)
# 7905  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7906  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7907  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7908  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7909  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7910  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7911  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7912  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7913  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7914  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7915  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
# 7916  Proteobacteria(100)  Gammaproteobacteria(100)  Enterobacteriales(100)
#
#                        Family                     Genus
# 0     Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 1     Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 2     Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 3     Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 4     Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 5     Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 6     Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7     Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 8     Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 9     Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 10    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 11    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 12    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 13    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 14    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 15    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 16    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 17    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 18    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 19    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 20    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 21    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 22    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 23    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 24    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 25    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 26    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 27    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 28    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 29    Enterobacteriaceae(100)  Escherichia-Shigella(98)
# ...                       ...                       ...
# 7887  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7888  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7889  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7890  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7891  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7892  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7893  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7894  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7895  Enterobacteriaceae(100)     Pseudocitrobacter(52)
# 7896  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7897  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7898  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7899  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7900  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7901  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7902  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7903  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7904   Enterobacteriaceae(99)     Pseudocitrobacter(37)
# 7905  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7906  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7907  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7908  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7909  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7910  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7911  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7912  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7913  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7914  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7915  Enterobacteriaceae(100)  Escherichia-Shigella(98)
# 7916  Enterobacteriaceae(100)  Escherichia-Shigella(98)
#
# [7917 rows x 14 columns]
